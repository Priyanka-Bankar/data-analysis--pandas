# %% [markdown]
# # Introduction

# %% [markdown]
# The dataset used in this project is 'California dataset' which has 10 colums and 20640 rows.The features of the dataset  are longitude(continous),latitude(continous) ,housing_median_age(discrete), total_rooms(discrete), total_bedrooms(continous), population(discrete), households(discrete), median_income(continous), median_house_value(discrete), ocean_proximity(categorical).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# let us first upload dataset into notebook using pd.read_csv command

# %%
house = pd.read_excel("C:/Users/Priyanka/Downloads/housing+(1).xlsx")
house
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# we can also see first and last 5 rows of dataset using pd.head and pd.tail function

# %%
house.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %% [markdown]
# we can also understand dataset by using info() function.

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# we can also understand the statistical analysis of dataset using describe().

# %%
house.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# **Q1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.**

# %% [markdown]
# - It is a univariate analyis.
# - column datatype is numerical(continuous).
# - we can use box plot or histogram to see distrinution.
# - using box plot we can also see skewness of the data.

# %%
# average median income = 3.870671
house["median_income"].mean()
# Out:
# 3.8706710029069766

# %%
# plot using seaborn
sns.histplot(data=house,x='median_income')
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %%
# plot using matplotlib.
plt.hist(house["median_income"], color='blue',edgecolor='black')
plt.title("Average Median Income")
plt.xlabel("Median Income")
plt.ylabel("Frequencies")
plt.grid(False)
plt.show()

# %%
# using boxplot
sns.boxplot(data=house,y='median_income')
# Out:
# <Axes: ylabel='median_income'>

# %% [markdown]
# ## Interpretation:
#
# - From above histogram or box plot we can see that average median_income is 3.78 and plot is positively skewed/right skewed.
# - which means median(3.53) is less than mean(3.87)
# - from this we can interpreat that their are some people which are receiving higher salries/income.
# - outliers also present .

# %% [markdown]
# **2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.**

# %% [markdown]
# - It is a univariate analyis.
# - column datatype is numerical(discrete).
# - we can use box plot or histogram to see distrinution.
# - using box plot we can also see skewness of the data.

# %%
# average housing median age --> int64
house["housing_median_age"].mean()
# Out:
# 28.639486434108527

# %%
# plot using seaborn
sns.histplot(data=house, x='housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
# housing median age 
# using matplotlib.

plt.hist(house["housing_median_age"], color='pink',edgecolor='black')
plt.title(" Housing Median Age Distribution")
plt.xlabel("Housing median age")
plt.ylabel("Frequencies")
plt.grid(False)
plt.show()

# %%
#using boxplot
sns.boxplot(data=house,y='housing_median_age')
# Out:
# <Axes: ylabel='housing_median_age'>

# %% [markdown]
# ## Interpretation
#
# - From above histogram or box plot we can see that average median_housing_age is 28.63 and plot is negatively/left skewed.
# - which means median(29.00) is greater  than mean(28.63).
# - we can also say that most houses has median_age  less than or equal to 29.

# %% [markdown]
# **Q3. Show with the help of visualization, how median_income and median_house_values are related?**

# %% [markdown]
# - It is a Bivariate Analysis
# - column datatype is continuous and discrete i.e numerical vs numerical
# - we can use scatterplot or line plot to see relation.
# - Use case - Finding correlation

# %%
 # scatter plot using seaborn
sns.scatterplot(data=house,x='median_income',y='median_house_value')
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %%
# scatter plot using matplotlib
plt.scatter(house['median_income'],house['median_house_value'],color='green',marker='h',edgecolor='black')
plt.xlabel('median income')
plt.ylabel('median house value')
plt.show()

# %% [markdown]
# # Interpretation
#
# From above plots we can see that variables are positively correlated. which means if the median_income increases median_house_value also increases.

# %% [markdown]
# **Q4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.**

# %%
# first check how many null values are there in total_bedroom column using isna()
house["total_bedrooms"].isna().sum()
# Out:
# 207

# %%
# delete record using dropna()
x = house["total_bedrooms"].dropna()
x
# Out:
# 0         129.0
# 1        1106.0
# 2         190.0
# 3         235.0
# 4         280.0
#           ...
# 20635     374.0
# 20636     150.0
# 20637     485.0
# 20638     409.0
# 20639     616.0
# Name: total_bedrooms, Length: 20433, dtype: float64

# %%
# check whether 207 records delete or not.
20640 - 20433 # should give 207 as answer
# Out:
# 207

# %% [markdown]
# **Q5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.**

# %%
miss_df = house.fillna(house["total_bedrooms"].mean())
miss_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
# to cross check whether values are replaced or not use iloc function


miss_df.iloc[285:295] 

# in excel index start from 2 and missing  value is at 292 row and in pandas index start with 0 so to get correct result we have to see two row above in excel index(ie 290th index) to check whether values are replaced with mean or not.
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 285    -122.17     37.77                  30         3326      746.000000
# 286    -122.18     37.78                  43         1985      440.000000
# 287    -122.18     37.78                  50         1642      322.000000
# 288    -122.17     37.78                  49          893      177.000000
# 289    -122.17     37.78                  52          653      128.000000
# 290    -122.16     37.77                  47         1256      537.870553
# 291    -122.16     37.77                  48          977      194.000000
# 292    -122.16     37.77                  45         2324      397.000000
# 293    -122.16     37.77                  39         1583      349.000000
# 294    -122.17     37.77                  39         1612      342.000000
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %% [markdown]
# **Q6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.**

# %%
def x(df,column):
    y = df[column].median()
    return y

x(house,'population')
# Out:
# 1166.0

# %% [markdown]
# **Q7. Plot latitude versus longitude and explain your observations.**

# %% [markdown]
# - latitude(float) vs langitude(float)
# - it is a bivariate analysis.
# - column datatype is continuous and continuous i.e numerical vs numerical
# - we can use scatterplot to see relationship.
# - use case - Finding correlation

# %%
# using seaborn

sns.scatterplot(data=house,x='latitude',y='longitude',marker='o',edgecolor='black',hue='ocean_proximity')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# ## Interpretation:
#
# From above plots we can see that variable latitude and longitude are negatively correlated. which means if values of latitude is increasing longitude is decreasing.

# %% [markdown]
# **Q8. Create a data set for which the ocean_proximity is ‘Near ocean’.**

# %%
temp_df = house[house['ocean_proximity'] == 'NEAR OCEAN']
temp_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %% [markdown]
# **Q9. Find the mean and median of the median income for the data set created in question 8.**

# %%
temp_df["median_income"].mean()
# Out:
# 4.0057848006019565

# %%
temp_df["median_income"].median()
# Out:
# 3.64705

# %%
#or to crosscheck
temp_df["median_income"].describe()
# Out:
# count    2658.000000
# mean        4.005785
# std         2.010558
# min         0.536000
# 25%         2.630525
# 50%         3.647050
# 75%         4.837400
# max        15.000100
# Name: median_income, dtype: float64

# %% [markdown]
# **Q10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.**

# %%
house["total_bedrooms_size"] = house["total_bedrooms"].apply(lambda x : 'small' if x<=10 else 'medium' if (x >= 11 and x<=1000)  else 'large')
house.iloc[95:150]
# here iloc() is used to cross check if lambda function  is worked or not.
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 95     -122.26     37.80                  36         5329          2477.0
# 96     -122.26     37.82                  31         4596          1331.0
# 97     -122.26     37.81                  29          335           107.0
# 98     -122.26     37.82                  22         3682          1270.0
# 99     -122.26     37.82                  37         3633          1085.0
# 100    -122.25     37.81                  29         4656          1414.0
# 101    -122.25     37.81                  28         5806          1603.0
# 102    -122.25     37.81                  39          854           242.0
# 103    -122.25     37.81                  52         2155           701.0
# 104    -122.26     37.81                  34         5871          1914.0
# 105    -122.24     37.82                  52         1509           225.0
# 106    -122.24     37.81                  52         2026           482.0
# ...
